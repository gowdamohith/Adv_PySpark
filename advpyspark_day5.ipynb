# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import udf
from pyspark.sql.types import StringType

# %%
spark = SparkSession.builder \
    .appName("Uppercase UDF Example") \
    .getOrCreate()

# %%
def to_uppercase(value):
    if value is not None:
        return value.upper()
    return None

# %%
uppercase_udf = udf(to_uppercase, StringType())

# %%
data = [
    ("Rohit", 25),
    ("Shreyas", 30),
    ("Virat", 35),
    (None, 40)
]
df = spark.createDataFrame(data, ["name", "age"])

# %%
df_with_upper = df.withColumn("name_upper", uppercase_udf(df["name"]))

# %%
df_with_upper.show()
# Out:
# +-------+---+----------+
# |   name|age|name_upper|
# +-------+---+----------+
# |  Rohit| 25|     ROHIT|
# |Shreyas| 30|   SHREYAS|
# |  Virat| 35|     VIRAT|
# |   NULL| 40|      NULL|
# +-------+---+----------+
